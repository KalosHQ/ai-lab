# %% [markdown]
# # Color Extraction Prototype
#
# Parallel Task: Extract dominant colors using K-Means.

# %%
from sklearn.cluster import KMeans
import cv2
import numpy as np

# TODO: Load image, crop clothing area, run KMeans
